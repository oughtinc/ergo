# %% [markdown]
# <a href="https://colab.research.google.com/github/oughtinc/ergo/blob/prediction-dashboard-fix/notebooks/src/prediction-dashboard.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Setup

# %%
# %%capture
# %pip install --quiet poetry  # Fixes https://github.com/python-poetry/poetry/issues/532
# %pip install --quiet git+https://github.com/oughtinc/ergo.git@f1bd4169f1ab3dc79a0c11cfc4313449ec739926

# %%
import ergo
import datetime
import pandas as pd;

# %%
# %load_ext google.colab.data_table

# %%
metaculus = ergo.Metaculus(username="oughtpublic", password="123456", api_domain="pandemic")

# %% [markdown]
# # Dashboard

# %% [markdown]
# ## Resolved questions

# %%
resolved_predictions = metaculus.make_questions_df(metaculus.get_questions_json(question_status="resolved", player_status="predicted", pages=9999))

# %%
resolved_predictions[["title", "resolve_time", "i_created", "url", "id"]]
# Out:
#                                                title  ...    id
# 0  When will El Paso County, Texas, experience it...  ...  4128
# 1  How many new infections will be reported in El...  ...  4137
# 2  What will the average number of reported daily...  ...  4170
# 3  What will the average number of reported daily...  ...  4152
#
# [4 rows x 5 columns]

# %% [markdown]
# ## Open questions

# %%
open = metaculus.make_questions_df(metaculus.get_questions_json(question_status="open", player_status="any", pages=9999))

# %% [markdown]
# ### Published on or after Mar 1 2020, closing in 2020

# %%
open_mar_or_after = open[open["publish_time"] > datetime.datetime(2020,3,1)]
and_closes_in_2020 = open_mar_or_after[open_mar_or_after["close_time"] <= datetime.datetime(2020,12,31)]

# %%
and_closes_in_2020
# Out:
#                                                    url  ... i_predicted
# 0    https://pandemic.metaculus.com/api2/questions/...  ...       False
# 3    https://pandemic.metaculus.com/api2/questions/...  ...       False
# 4    https://pandemic.metaculus.com/api2/questions/...  ...       False
# 5    https://pandemic.metaculus.com/api2/questions/...  ...       False
# 6    https://pandemic.metaculus.com/api2/questions/...  ...       False
# ..                                                 ...  ...         ...
# 125  https://pandemic.metaculus.com/api2/questions/...  ...       False
# 126  https://pandemic.metaculus.com/api2/questions/...  ...       False
# 127  https://pandemic.metaculus.com/api2/questions/...  ...       False
# 128  https://pandemic.metaculus.com/api2/questions/...  ...       False
# 129  https://pandemic.metaculus.com/api2/questions/...  ...       False
#
# [88 rows x 30 columns]
