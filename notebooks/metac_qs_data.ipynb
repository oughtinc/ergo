# %% [markdown]
# # Setup

# %%
# %%capture
# !pip install --progress-bar off poetry
# !pip install --progress-bar off git+https://github.com/oughtinc/ergo.git@e92c684d45ebebea0d6bb43172b284fc53d067fc

# %%
import warnings
warnings.filterwarnings(action="ignore", category=FutureWarning)
warnings.filterwarnings(action="ignore", module="plotnine")

# %%
import pandas as pd
from datetime import datetime

import ergo
from ergo.platforms.metaculus.question import MetaculusQuestion, LinearQuestion, LogQuestion, ContinuousQuestion

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Get questions

# %% [markdown]
# Get all *open* questions on the specified subdomains.
#
# NOTES:
# 1. log date questions are excluded because Ergo currently can't handle them
# 2. questions that are in multiple subdomains will be included multiple times, once for each subdomain

# %%
subdomains = ["www", "pandemic"]

# %%
qs = []

for subdomain in subdomains:
    metaculus = ergo.Metaculus(username="oughtpublic", password="123456", api_domain=subdomain)
    qs = qs + metaculus.get_questions(question_status="open", pages=99999, load_detail=False)

# %%
# For questions with open boundaries,
# the undetailed version of these questions is missing
# the probability above and below the question bounds, which we'd like to have.
# So, fetch the full question data.
for q in qs:
    if getattr(q, "low_open", False) or getattr(q, "high_open", False):
        q.refresh_question()

# %%
exemplar_q_id = 3530

# %%
exemplar_q = metaculus.get_question(exemplar_q_id)

# %%
qs_df = exemplar_q.to_dataframe(qs)

# %% [markdown]
# # Get question metadata

# %% [markdown]
# ## Get all of the metadata already on the question

# %% [markdown]
# Get the field names from the question JSON from Metaculus:

# %%
metaculus_json_fields = list(exemplar_q.data.keys())

# %% [markdown]
# Get the property names from the MetaculusQuestion and ContinuousQuestion classes:

# %%
def properties(some_class):
    """
    Get all @properties of a class
    """
    class_items = some_class.__dict__.items()
    return [name for (name, value) in class_items if isinstance(value, property)]

# %%
question_properties = properties(MetaculusQuestion)

# %%
continuous_question_properties = properties(ContinuousQuestion)

# %%
# %%capture
q_fields = metaculus_json_fields + question_properties + continuous_question_properties

simple_fields = [field for field in q_fields if type(getattr(exemplar_q, field)) in [bool, int, float, str, datetime]]

# This property causes an exception for some reason.
# Didn't seem worth investigating
simple_fields.remove("question_range_width")

for field in simple_fields:
    qs_df[field] = [getattr(q, field, None) for q in qs]

# %% [markdown]
# ## Generate and add more metadata

# %%
def get_p_outside(q):
    if not hasattr(q, "latest_community_percentiles"):
        return None

    # q.latest_community_percentiles is a float for binary questions:
    # https://github.com/oughtinc/ergo/pull/378
    if type(q.latest_community_percentiles) == float:
        return None
    
    return q.latest_community_percentiles["low"] + (1 - q.latest_community_percentiles["high"])

# %%
metadata_columns = {
    "type": lambda q: type(q).__name__,
    "subdomain": lambda q: q.metaculus.api_domain,
    "num_boundaries_open": lambda q: int(q.low_open) + int(q.high_open) if hasattr(q, "low_open") else None,
    "question_scale_low": lambda q: q.scale.low if hasattr(q, "scale") else None,
    "question_scale_high": lambda q: q.scale.high if hasattr(q, "scale") else None,
}

# %%
for (name, fn) in metadata_columns.items():
    qs_df[name] = [fn(q) for q in qs]

# %% [markdown]
# ## Select and reorder columns

# %% [markdown]
# We have these columns:

# %%
qs_df[qs_df["id"] == exemplar_q_id].head(1)
# Out:
#        id                                              title  \
# 277  3530  How many people will die as a result of the 20...
#
#                                  question_url subdomain         type  \
# 277  https://www.metaculus.com/questions/3530       www  LogQuestion
#
#      num_boundaries_open low_open high_open  p_outside question_scale_low  \
# 277                  2.0     True      True      0.028                200
#
#     question_scale_high  anon_prediction_count           last_activity_time  \
# 277           100000000                  101.0  2020-06-25T18:13:37.440708Z
#
#      votes  comment_count                 created_time publish_time  \
# 277    149            234  2020-01-25T04:09:23.208127Z   2020-01-27
#
#               close_time         resolve_time author_name  \
# 277  2020-11-01 00:00:00  2021-01-01 00:00:00       Jgalt
#
#                        last_read has_predictions  activity  \
# 277  2020-06-19T03:27:38.264689Z            True  6.706319
#
#                               title_short
# 277  COVID-19 related deaths before 2021:

# %% [markdown]
# Select all the ones that might plausibly be useful, and put them in a reasonable order:

# %%
qs_df = qs_df[[
    "id",
    "title",
    "question_url",
    "subdomain",
    "type",
    "num_boundaries_open",
    "low_open",
    "high_open",
    "p_outside",
    "question_scale_low",
    "question_scale_high",
    "anon_prediction_count",
    "last_activity_time",
    "votes",
    "comment_count",
    "created_time",
    "publish_time",
    "close_time",
    "resolve_time",
    "author_name",
    "last_read",
    "has_predictions",
    "activity",
    "title_short"
]]

# %%
qs_df[qs_df["id"] == exemplar_q_id].head(1)
# Out:
#        id                                              title  \
# 277  3530  How many people will die as a result of the 20...
#
#                                  question_url subdomain         type  \
# 277  https://www.metaculus.com/questions/3530       www  LogQuestion
#
#      num_boundaries_open low_open high_open  p_outside question_scale_low  \
# 277                  2.0     True      True      0.028                200
#
#     question_scale_high  anon_prediction_count           last_activity_time  \
# 277           100000000                  101.0  2020-06-25T18:13:37.440708Z
#
#      votes  comment_count                 created_time publish_time  \
# 277    149            234  2020-01-25T04:09:23.208127Z   2020-01-27
#
#               close_time         resolve_time author_name  \
# 277  2020-11-01 00:00:00  2021-01-01 00:00:00       Jgalt
#
#                        last_read has_predictions  activity  \
# 277  2020-06-19T03:27:38.264689Z            True  6.706319
#
#                               title_short
# 277  COVID-19 related deaths before 2021:

# %% [markdown]
# ## Explanations of some important fields
# - `low_open`: Is the lower boundary of the question open? (only applies to ContinuousQuestions)
# - `high_open`: Is the upper boundary of the question open? (only applies to ContinuousQuestions)
# - `p_outside`: How much of the total probability mass of the community prediction is outside the question range? (only applies to ContinuousQuestions)
# - `anon_prediction_count`: Seems to be a proxy for the number of predictions. See "Data notes" below.
# - `last_activity_time`: Seems to be a quick proxy for the time of the last prediction on the question. See "Data notes" below.
# - `comment_count`: How many comments have been left on this question?
# - `created_time`: When did the author of the question create it? (I think)
# - `publish_time`: When was the question published to all Metaculus users?
# - `close_time`: After what time are predictions on this question no longer allowed?
# - `resolve_time`: When can the question be resolved, i.e. when will the answer be known?

# %% [markdown]
# ## Data notes:
# 1. `anon_prediction_count` is the closest thing I could find to a count of number of predictions, but I'm not really sure how it relates to the number of predictions. In my testing:
#     1. It seems to always be the same as the length of `prediction_timeseries`
#     2. It seems to be correlated with something about the number of predictions shown. E.g.
#         1. it's 101 for this question where the community prediction is shown: https://www.metaculus.com/questions/3530/how-many-people-will-die-as-a-result-of-the-2019-novel-coronavirus-covid-19-before-2021/.
#         2. While it's 0 for this question where the community prediction is not shown yet: https://www.metaculus.com/questions/4614/when-will-directly-removing-carbon-dioxide-from-the-atmosphere-be-economically-feasible/
#     3. I couldn't get it to increment. I tried:
#         1. making a new prediction with an account that had already predicted on the question
#         2. making a prediction with an account that had never predicted on that question before.
# 2.`last_activity_time` seems like the most obvious easy proxy for when the most recent prediction was made. However, I'm not sure how reliable it is.
#     1. It did not update when I made a new prediction from an account that had already predicted on the question previously
#     2. It may update when people leave comments or at other times
#     3. Alternatively, we could use the last time from the `prediction_timeseries`, but that also doesn't seem to update every time someone makes a prediction
# 3. To get the datetime of the last posted comment, I think we'd need to retrieve it from a separate API (prob at least 30 min of work, maybe more like hours), so I haven't tried
# 4. Log date questions are excluded here because Ergo can't handle them yet.

# %% [markdown]
# # View data

# %% [markdown]
# ## Export as csv
#
# (For use when running locally in `ergo/notebooks`)

# %%
# qs_df.to_csv("../ergo/contrib/metac_qs_data/metac_qs_data.csv", index=False, float_format='%.20f')

# %% [markdown]
# A version of this CSV is uploaded as a [Google Sheet](https://docs.google.com/spreadsheets/d/1Aii_IkUTiJH6t14n2lhwhu4PJJjlTz6X5vdEi5gPGa0/edit#gid=1305569144).

# %% [markdown]
# ## View all questions

# %%
qs_df
# Out:
#        id                                              title  \
# 0    4694  What will Gross World Product be in 2047, in t...
# 1    4645  If Conservatives win the next UK general elect...
# 2    4644  If Labour wins the next UK general election, w...
# 3    4692  When will The Boring Company tunnel faster tha...
# 4    4680  When will the population size of India surpass...
# 5    4688  What will the real GDP/capita of the USA be in...
# 6    4683  Will the border conflict between India and Chi...
# 7    4682  Will at least 500 Indians die in clashes along...
# 8    4697  [short fuse] Given that the NYT publishes an a...
# 9    4681  How many paid memberships will Netflix have wo...
# 10   4459  When will the first genome-wide association st...
# 11   4306  Which Artemis Moon Mission landing system will...
# 12   4670  Will the XENON1T experiment soon report a dete...
# 13   4659  What will be the difference in July 2020 perfo...
# 14   4656  What will voter turnout be for the US 2020 pre...
# 15   4661  What fraction of the US Congress will be held ...
# 16   4456  Will the United States test a nuclear weapon b...
# 17   4665  When will Ninja first lose the top spot as the...
# 18   4658  How many YouTube views will Despacito have on ...
# 19   4662  What fraction of US Congress seats will be hel...
# 20   4663  How long will it take to listen to every episo...
# 21   4657  When will @JoeBiden reach 10% as many Twitter ...
# 22   4666  How many people will die due to Ebola infectio...
# 23   4660  How many episodes of the FiveThirtyEight Polit...
# 24   4650  Will Republicans win both halves of Congress +...
# 25   4633                              Was peak oil in 2019?
# 26   4527  Will the S&P 500 hit 10,000 points by the end ...
# 27   4637            Will the S&P 500 close higher for 2020?
# 28   4614  When will directly removing carbon dioxide fro...
# 29   4622  How many more Starship prototypes will be dest...
# 30   4646  What will total enrollment for recent US high ...
# 31   4596  What will the percentage difference between fu...
# 32   4607  Will California Assembly Bill 3155 be chaptere...
# 33   4628  Will one of GiveWell's 2019 top charities be e...
# 34   4615  What annual real return will the S&P 500 reali...
# 35   4586  If Biden becomes president, will the sentencin...
# 36   4609  If President Trump loses the 2020 election, wi...
# 37   4630  Will Metaculus Inc. host a prediction market p...
# 38   4603  What will the US Q3 2020 GDP growth rate be, a...
# 39   4617           Will 2020 be the warmest year on record?
# 40   4584  What % of money held in all US DAFs will be ex...
# 41   4608  In 2024, what percentage of surveyed Americans...
# 42   4606                      When will we have a new Pope?
# 43   4585  What annual real return will the global stock ...
# 44   4588  When will SpaceX's Starship carry a human to o...
# 45   4055      Will the first AGI be based on deep learning?
# 46   4554  Will more than one entrant achieve a perfect s...
# 47   4319  Longbets series: By 2040 will the percentage o...
# 48   4219  Will large scale solar radiation management be...
# 49   4544  Will there be fewer Kea parrots in 2030 than t...
# 50   4050  What will the maximum world real GDP growth in...
# 51   4249  When will there be a vegan cheese indistinguis...
# 52   4443  When will China surpass the United States econ...
# 53   4572  How much transit activity will there be in the...
# 54   4573  How much transit activity will there be in the...
# 55   4574  How much transit activity will there be in the...
# 56   4568  How much transit activity will there be in New...
# 57   4570  How much transit activity will there be in New...
# 58   4569  How much transit activity will there be in New...
# 59   4562  Will the artist who performs 2020’s UK Christm...
# 60   4559  Will the next winner of the Booker Prize be fe...
# 61   4451  When will the first 100 million digit prime nu...
# 62   4563             Will 2020’s UK Christmas #1 be a joke?
# 63   4518  How many billions of parameters will the large...
# 64   4564  Will a TikTok user hit 100m followers by the e...
# 65   4555  Will Trump's pants catch fire on at least five...
# 66   4561  Will J.K. Rowling’s “The Ickabog” reach #1 on ...
# 67   4556  Will 3Blue1Brown begin a new video series in t...
# 68   4511  How long would humanity take to rebound from a...
# 69   4565  Will more than five of the ten highest grossin...
# 70   4524  Will the US conduct a nuclear test explosion b...
# 71   4444  What will be the highest value of the U.S. Pri...
# 72   4290  Will NAD+ boosters be shown in a systematic re...
# 73   3725  When will a private fusion company first repor...
# 74   4536        Will the US see widespread rioting in 2020?
# 75   4516  Will California Senate Bill 902 be chaptered i...
# 76   4433  If Biden becomes president, will there be an e...
# 77   4441           When will be the next "Great Power" war?
# 78   4121         Will Italy leave the Eurozone before 2023?
# 79   1059  Before 2051, will a meteor cause more injuries...
# 80   3913  When will a vaccine for HIV be administered to...
# 81   4439          When will North Korea become a democracy?
# 82   4446  How many structures will be destroyed by wildf...
# 83   4440  What rank will the United States be on the ine...
# 84   4425  Will Israel annex  the Jordan Valley in the We...
# 85   4442  What will be the gross receipts of the SENS Re...
# 86   4418  What is the greatest number of people who, for...
# 87   4403  Will Amazon ($AMZN) make a public offer to acq...
# 88   4429  By 1 January 2067, medical interventions for h...
# 89   4409   Will one of the first AGI claim to be conscious?
# 90   4415  Will American Airlines file for bankruptcy pro...
# 91   2711  Will a Guaranteed Minimum Income introduced in...
# 92   4125  What will be the first year during which most ...
# 93   3657  If a single-payer healthcare system is adopted...
# 94   4119   What will be the S&P 500 end-of-day low in 2020?
# 95   4235  When will multi-modal ML out-perform uni-modal...
# 96   4237  How many months of 2020 will be declared "eart...
# 97   4390  What will be the lowest cost per kilogram, in ...
# 98   4265  How much exercise can you do before it starts ...
# 99   4364  When will the US national debt reach $50 trill...
# 100  4354  Will Joe Biden be the Democratic Party nominee...
# 101   593  If alien life is discovered in the Solar Syste...
# 102  4127  Will a member of the Trump family be the Repub...
# 103  4183  How many deaths related to COVID-19 will be re...
# 104  3277  What will be the average overall Global Health...
# 105  4207  Will at least 200,000 COVID-19 deaths be repor...
# 106  1444  Will an openly LGBTQ person be elected Preside...
# 107   953  Will Mike Pence be elected president of the Un...
# 108  4264  How many years after the silver Turing Test is...
# 109  4328  Will a total sum amounting to at least 10% of ...
# 110  4349  Will the Harvard endowment be larger in 2119 t...
# 111   480  If chess is solved before 2080, must perfect p...
# 112  4110  Assuming some humans are alive, what will be t...
# 113  4291  When will the suspension of incoming travel to...
# 114  4334  If chess is solved before 2080, must perfect p...
# 115   804               Will question 1000 resolve positive?
# 116  4332  How much will GiveWell guess it will cost to g...
# 117  4318  Will EA Global London 2020 be cancelled or res...
# 118  4101  If Donald Trump is reelected president, what w...
# 119  4123  After an AGI is created, how many months will ...
# 120  4333  What will be the Democracy Index of the United...
# 121  4051  Will Alcor offer the use of a fixative during ...
# 122   952  In which month will there first be 20,000 new ...
# 123  3613  How many posts will there be on the Effective ...
# 124  4061  Will Any Major AI Company Commit to an AI Wind...
# 125  3647  Longbets series: By 2025 will the scientific e...
# 126  4053  What will be the Alexa Traffic Rank for Metacu...
# 127  3648  Longbets series: By 2029 will a computer have ...
# 128  4209  When will a human chess player reach a FIDE ra...
# 129  4232  When will AI out-perform humans on argument re...
# 130  4116                       When will Disneyland reopen?
# 131  4314  What will the magnitude of most severe earthqu...
# 132  4313  Will (at least one) magnitude 6.0 or greater e...
# 133  4052  If cryonics is at some point offered for free,...
# 134  4224  Will Stephen Wolfram or his co-authors, Jonath...
# 135  4171  How much karma will the top LessWrong post in ...
# 136  4118  Will there be a positive transition to a world...
# 137  4118  Will there be a positive transition to a world...
# 138  4078  What will the size of Singapore's total foreig...
# 139  4048  How many cents will it cost a typical consumer...
# 140  4047  What will the top GPU score be on Passmark on ...
# 141  4046  What will the top CPU score be on Passmark on ...
# 142  4215  What will be the real world GDP on the year AG...
# 143  4220  Will Wayne Hsiung be elected mayor of Berkeley...
# 144  3999  What will the peak population of Antarctica be...
# 145  3840  When will Nintendo release a console capable o...
# 146  3618     When will the United States admit a new state?
# 147  4097  Will China Oceanwide Holdings Group Co., Ltd. ...
# 148  3777  Will reducing wild animal suffering be a mains...
# 149  3812  Will Valve release a game before 2030 with 3 i...
# 150  4083  What will be the relative severity of the next...
# 151  4036  What will China's unemployment rate be for Q1 ...
# 152  3629  Will the National Popular Vote Interstate Comp...
# 153  4043   When will OpenAI unveil their secret AI project?
# 154  4094  How many years will caloric restriction be dem...
# 155  4027  What proportion of Senate Republican incumbent...
# 156  4028  What proportion of Senate Democratic incumbent...
# 157  4026  What proportion of House Republican incumbents...
# 158  4037  Will a sitting US president not seek reelectio...
# 159  3992  What fraction of United States adults will be ...
# 160  4028  What proportion of Senate Democratic incumbent...
# 161  3125  Will the United States continue to be among th...
# 162  4066  When will a SARS-CoV-2 vaccine candidate that ...
# 163  3867  If there is a WW3, what longitude will it star...
# 164  3868  If there is a WW3, what latitude will it start...
# 165  4033          What will inflation be in the US in 2021?
# 166  4032       What will unemployment be in the US in 2021?
# 167  4054  How many reviews will Toby Ord's book The Prec...
# 230  3749  Will the key to any pre-2020 WikiLeaks insuran...
# 231  3742  Will the global atmospheric CO₂ concentration ...
# 232  3739  Will it turn out that the Keto diet is both sa...
# 233  3743  When will the global annual mean surface air t...
# 234  3734  Will JHU CSSE's COVID-19 dashboard remain open...
# 235  3715  Before 2025, will at least two public health a...
# 236  3681  Will it turn out that Covid-19 originated insi...
# 237  3708  What will the lower limit in the IPCC's ‘likel...
# 238  3656  Will a 100 trillion parameter deep learning mo...
# 239  3701  What will the maximum increase in global annua...
# 240  3689  Will Yang get 200k donors or more in the 2024 ...
# 241  3696     Is the Diamond Princess done as a cruise ship?
# 242  3684  When will a quantum computer running Shor's al...
# 243  3652  How much wind energy will be consumed globally...
# 244  3678  How much greenhouse gas will be emitted global...
# 245  3679  How much higher will the annual mean surface a...
# 246  3682  Before the end of 2024 will at least two publi...
# 247  3671  Will it turn out that Bloomberg manipulated 20...
# 248  3616  Will a new amendment to the US Constitution be...
# 249  3612  Will Elon Musk be the richest person in the wo...
# 250  3653  How much solar energy will be consumed globall...
# 251  3665  Are we on path for IPCC's 'middle-of-the-road'...
# 252  3626  What will the world real GDP growth rate be in...
# 253  3623  When will the English Wikipedia have 10 millio...
# 254  3608  Will the majority of leading cosmologists in 2...
# 255  3622  What will the Harvard admit rate be for the un...
# 256  3619  How many nations will there be in the United N...
# 257  3630  Will Donald Trump tweet that Bernie Sanders is...
# 258  3623  When will the English Wikipedia have 10 millio...
# 259  3626  What will the world real GDP growth rate be in...
# 260  3617     Will the US supreme court change size by 2050?
# 261  3611  If Trump loses the election in 2020, will he m...
# 262  3608  Will the majority of leading cosmologists in 2...
# 263  3588  Will Stacey Abrams be elected president in or ...
# 264  3592  When will the volume-weighted average battery ...
# 265  3591  When will the volume-weighted average battery ...
# 266  3600  Will Iowa host another "first in the nation" D...
# 267  3580  What will the global weighted-average levelize...
# 268  3593  Will renewable energy contribute 25.00%, or le...
# 269  3581  What will the global weighted-average levelize...
# 270  3582  What will the average growth rate be, of total...
# 271  3535  How many geoengineering international treaties...
# 272  3531  Will the star Betelgeuse be observed to go sup...
# 273  3534  How many geoengineering-related papers will be...
# 274  3528  Will a geoengineering act of Congress become U...
# 275  3541  How many new electric vehicles will be registe...
# 276  3542  How many new electric vehicles will be registe...
# 277  3530  How many people will die as a result of the 20...
# 278  3525  How many total unique visitors will download D...
# 279  3514  How many judges will the US Senate confirm in ...
# 280  3520  What will the cost of energy of utility-scale ...
# 281  3521  What will the cost of energy of utility-scale ...
# 282  3522       When will the Doomsday Clock reach midnight?
# 283  3518  When will we be able to predict at least 10% o...
# 284  3515  When will the first humans land successfully o...
# 285  3519             One Million Martian Residents by 2075?
# 286  3513  If Trump loses the election, will he contest t...
# 287  3517  Will there be a global thermonuclear war by 2070?
# 288  3503  Will the Democrats hold the US House of Repres...
# 289  3501  Will a third-party candidate get more than 5% ...
# 290  3508  When will Trikafta become available for Cystic...
# 291  3516  Will Beyond Meat outperform the the general U....
# 292  3478  How many patients will be in cryonic suspensio...
# 293  3507  Will EQRx get at least one drug approved by th...
# 294  3504  Will Democrats win both halves of Congress + P...
# 550  1628  What will be the longest verified human lifesp...
# 551  1630  What percentage of US residents will be aged 1...
# 552  1624  Will a mouse be confirmed to have lived for 2,...
# 553  1620  What will be the heaviest payload put into LEO...
# 554  1618              Is the Zuma satellite still in orbit?
# 555  1604  Ragnarök Question Series: if a global climate ...
# 556  1600  The Top500's total sum in 2030 as a multiple o...
# 557  1598            Will Elon Musk (attempt to) go to Mars?
# 558  1591  Will the impact of the Effective Altruism move...
# 559  1596  What year will the 2˚C climate threshold be cr...
# 560  1585  Ragnarök Question Series: if a nuclear catastr...
# 561  1537          When will the first cloned human be born?
# 562  1568  Will we detect an exoplanet atmosphere with >5...
# 563  1579  Will China be the World's largest economy in a...
# 564  1574              What will the World's GDP be in 2028?
# 565  1576        Fewer than 375M in extreme poverty by 2030?
# 566  1558  The Rise and Fall of the Banana: Will the curr...
# 567  1552  Is non-theism (atheists and agnostics) growing...
# 568  1536  Will a third LIGO detector be built in India b...
# 569  1538  Will Metaculus predict that artificial intelli...
# 570  1540  How much less global warming if the US resumes...
# 571  1539                      3.6°C global warming by 2100?
# 572  1535  Will most protons that currently make up Earth...
# 573  1088  When will the last member of our species, homo...
# 574  1085      When will the student loan debt bubble "pop"?
# 575  1519  When will the total number of people who have ...
# 576  1515  Do humans have functionally important neurogen...
# 577  1492  What will be Top500's #1 performing supercompu...
# 578  1503  How many NASA "space launch system" (SLS) laun...
# 579  1502  Ragnarök Question Series: If a global catastro...
# 580  1500  Ragnarök Question Series: If a global catastro...
# 581  1494  Ragnarök Question Series: If a global catastro...
# 582  1501  Ragnarök Question Series: If a global catastro...
# 583  1495  Ragnarök Question Series: If a global catastro...
# 584  1493  Ragnarök Question Series: By 2100 will the hum...
# 585  1482  What percentage of Americans will be considere...
# 586  1481  When will either the Democratic or Republican ...
# 587  1476       Will NASA land people on Mars prior to 2030?
# 588  1480  Will any intelligent living being (human desce...
# 589  1469      Will we know what Dark Matter is before 2050?
# 590  1468      Will Xi Jinping keep leading China past 2022?
# 591  1457  Will Angela Merkel remain chancellor after the...
# 592  1454  A freer China? Chinese political rights and ci...
# 593  1434  When will India send their first own astronaut...
# 594  1435  When will the longest spaceflight of any one p...
# 595  1432  Will humans have a sustainable off-world prese...
# 596  1433  Will the fraction of American 18-24 year-olds ...
# 597  1416                   When will one TeraFlOPS cost $1?
# 598  1408  Does P = NP? Informally: If the solution to a ...
# 599  1343  Drake's Equation Question Set: for how many ye...
# 600  1402  Will Parker Solar Probe survive its 24 loops a...
# 601  1385  Qualia Research Institute Question Series: Wil...
# 602  1394                      Will AI progress surprise us?
# 603  1342  Drake's Equation Question Set: What fraction o...
# 604  1384  Qualia Research Institute Question Series: Wil...
# 605  1339  Drake's Equation Question Set: what is the ave...
# 606  1341  Drake's Equation Question Set: on what fractio...
# 607  1340  Drake's Equation Question Set: on what fractio...
# 608  1338  Drake's Equation Question Set: what fraction o...
# 609  1061         Will there be a 9 foot tall human by 2075?
# 610  1332  Will global malaria mortality rates be reduced...
# 611  1348  Will a mission to land a spacecraft on Europa ...
# 612  1337  Drake's Equation Question Set: 1st Parameter R...
# 613  1321                 Will Ray Kurzweil be proven right?
# 614  1139  Will a scientific mission to the outer solar s...
# 615  1100         Will Trump be reelected president in 2020?
# 616  1090  Will we get through the 21st century without a...
# 617  1079       Will Elon Musk (eventually) lose his appeal?
# 618  1052  Will there be a city on Earth with a populatio...
# 619  1058  Will humanity (essentially) run out of at leas...
# 620  1056  How long will the Great Pyramids be recognizable?
# 621  1011  Will Roe v. Wade be formally overturned within...
# 622   943  When will we get the last communication from V...
# 623  1002  Any progress in human lifespan enhancement by ...
# 624   981  Will cannabis be removed from Schedule I of th...
# 625   980  Will Tesla become the largest car company in t...
# 626   974  What will be the value of the (herein describe...
# 627   968  Will cost-adjusted IT technology be worse than...
# 628   969     When will commercial supersonic flight return?
# 629   957    Will Donald Trump serve time in jail or prison?
# 630   915  Will we discover clear evidence of proton deca...
# 631   916  Will another 9/11 on U.S. soil be prevented at...
# 632   917  Will a space elevator successfully be built by...
# 633   899  Will the world's richest person in 2033 have a...
# 634   841                      Will Metaculus exist in 2030?
# 635   824  Will a practical nuclear fusion reactor first ...
# 636   808  Will Europa be the first place humanity will d...
# 637   797  Will Puerto Rico become a US state prior to 2035?
# 638   736  Will there be a complete 4 year interval in wh...
# 639   737         Will SpaceX land anything on Mars by 2030?
# 640   735           When will there be a mile-high building?
# 641   684  By 2025 will someone be able to hold his/her b...
# 642   686  Will a human made spaceship enter the Venusian...
# 643   665                          Kessler syndrome by 2050?
# 644   658     Will we reach the island of stability by 2050?
# 645   600  Will a sample of negative energy be produced b...
# 646   614             Will there be a Vegan Country by 2100?
# 647   610  Will our current peace be shorter than the Pax...
# 648   606     Answer to signal broadcast into space by 2045?
# 649   605                   How much global warming by 2100?
# 650   604  Will gravitational waves from the merger of su...
# 651   594            Increased off-world population in 2050?
# 652   587                          World Population in 2050?
# 653   570          A major United States earthquake by 2023?
# 654   585                        2˚C global warming by 2100?
# 655   579           Will VR or AR Headsets dominate by 2025?
# 656   578                    Will humans go extinct by 2100?
# 657   523  Resolution of the Density Conjecture for Newto...
# 658   512  Will an AI system do credibly well on a full m...
# 659   513  Will the first commercial hyperloop system be ...
# 660   504  How many subscribers will Netflix have by Augu...
# 661   492  With an international nuclear weapons ban in p...
# 662   491  Will China achieve its Paris Climate Agreement...
# 663   489  Will the European Union meet its 2030 targets ...
# 664   477  Efficacy confirmation of a new Alzheimer's tre...
# 665   455  If you die today and get cryonically frozen, w...
# 666   397                                  Robocup Challenge
# 667   384         Human-machine intelligence parity by 2040?
# 668   375           The end of the EU as we know it by 2026?
# 669   372  Will human brain emulation be the first succes...
# 670   353      Will someone born before 2001 live to be 150?
# 671   349     Will SpaceX land people on Mars prior to 2030?
# 672   161                             Will the Universe end?
# 673  4685  How many cases of end-stage renal disease will...
# 674  4648  What mean percentage of students will be serve...
# 675  4649  What percentage of recent college graduates wi...
# 676  4646  What will total enrollment for recent US high ...
# 677  4647  How much money will the federal government spe...
# 678  4596  What will the percentage difference between fu...
# 679  4595  Will the nominal salaries of tenured professor...
# 680  4594  What will the Cohort College Participation Rat...
# 681  4598  What will the percent difference for inflation...
# 682  4455  What will be the U.S. age-adjusted stroke deat...
# 683  4602  What will state expenditure from state and loc...
# 684  4601  If the current political presidential administ...
# 685  4603  What will the US Q3 2020 GDP growth rate be, a...
# 686  4508  How many EU countries will (re)-introduce mand...
# 687  4120  How will Sweden and Finland's relative HDI cha...
# 688  4259  What will be the ratio of COVID-19 deaths per ...
# 689  4303  How will Sweden and Finland's relative Fragile...
# 690  4572  How much transit activity will there be in the...
# 691  4573  How much transit activity will there be in the...
# 692  4568  How much transit activity will there be in New...
# 693  4568  How much transit activity will there be in New...
# 694  4569  How much transit activity will there be in New...
# 695  4570  How much transit activity will there be in New...
# 696  4432  When will U.S. tech workers return to the office?
# 697  4536        Will the US see widespread rioting in 2020?
# 698  4420  When will the U.S. code "National All-Hazards ...
# 699  4421  Will there be a ‘second wave’ of COVID-19 deat...
# 700  4431  How many deaths due to vaccine-preventable dis...
# 701  4430  How many deaths due to vaccine-preventable dis...
# 702  4407  When will a government first require a positiv...
# 703  4406  When will a SARS-CoV-2 vaccine candidate that ...
# 704  4412  How many cases of pediatric multisystem inflam...
# 705  4413  How many deaths due to pediatric multisystem i...
# 706  4416  Will pediatric multisystem inflammatory syndro...
# 707  4347  When will daily commercial flights exceed 75,000?
# 708  4019  When will Amazon offer an in-home diagnostic t...
# 709  4081  Will any US State mandate COVID-19 diagnostic ...
# 710  4400  By August 1, how many tests for COVID-19 will ...
# 711  4365  What will be the list price for a 10-day treat...
# 712  4362  If a SARS-CoV-2 vaccine is administered to at ...
# 713  4183  How many deaths related to COVID-19 will be re...
# 714  4353  Will the WHO recommend SARS-CoV-2 airborne pre...
# 715  3277  What will be the average overall Global Health...
# 716  4207  Will at least 200,000 COVID-19 deaths be repor...
# 717  4291  When will the suspension of incoming travel to...
# 718  4318  Will EA Global London 2020 be cancelled or res...
# 719  4312  Will the next peak in COVID-19 hospitalization...
# 720  4309  When will the first antiviral therapy demonstr...
# 721  4116                       When will Disneyland reopen?
# 722  4315  When will an antiviral therapy that demonstrat...
# 723  4310  How many in the state of California will have ...
# 724  4078  What will the size of Singapore's total foreig...
# 725  4208  Will at least 400,000 COVID-19 deaths be repor...
# 726  4205  What will be the difference between all cause ...
# 727  4156  How many PHEICs will the WHO declare between 2...
# 728  4158  Will the number of confirmed COVID-19 cases in...
# 729  4155  What portion of in-hospital cases in El Paso C...
# 730  4154  What portion of in-hospital patients with Covi...
# 731  4084  Will Australia experience a resurgence of COVI...
# 732  4185  What will the unemployment rate be in El Paso ...
# 733  4102  When will Uber reinstate the carpooling option...
# 734  4104  When will Uber reinstate the carpooling option...
# 735  4105  When will Uber reinstate the carpooling option...
# 736  4109  What will be the Airbnb occupancy rate in the ...
# 737  4103  When will Uber reinstate the carpooling option...
# 738  4091  Will Stanford University hold in-person classe...
# 739  4083  What will be the relative severity of the next...
# 740  4064  When will a SARS-CoV-2 vaccine candidate demon...
# 741  4077  Will the existing Bacillus Calmette-Guerin (BC...
# 742  4076  Will a SARS-CoV-2 vaccine that induces a broad...
# 743  4075  Will a RNA SARS-CoV-2 vaccine candidate be app...
# 744  4074  Will a SARS-CoV-2 vaccine candidate whose deve...
# 645  6.681274e-17           Will a sample of negative energy be prod
# 646  5.901099e-15             Will there be a Vegan Country by 2100?
# 647  6.994544e-12           Will our current peace be shorter than t
# 648  1.022810e-25           Answer to signal broadcast into space by
# 649  2.198126e-01                   How much global warming by 2100?
# 650  2.823085e-10           Will gravitational waves from the merger
# 651  1.391799e-07            Increased off-world population in 2050?
# 652  7.224641e-09                          World Population in 2050?
# 653  5.398968e-01           A major United States earthquake by 2023
# 654  1.047533e-09                        2˚C global warming by 2100?
# 655  1.594177e-10           Will VR or AR Headsets dominate by 2025?
# 656  5.240912e-08                    Will humans go extinct by 2100?
# 657  8.351859e-20           Resolution of the Density Conjecture for
# 658  5.255940e-13           Will an AI system do credibly well on a
# 659  5.733069e-22           Will the first commercial hyperloop syst
# 660  3.976194e-08           How many subscribers will Netflix have b
# 661  7.914203e-08           With an international nuclear weapons ba
# 662  2.999109e-13           Will China achieve its Paris Climate Agr
# 663  2.098404e-20           Will the European Union meet its 2030 ta
# 664  7.361343e-08           Efficacy confirmation of a new Alzheimer
# 665  4.058278e-09           If you die today and get cryonically fro
# 666  4.353138e-13                                  Robocup Challenge
# 667  3.755364e-08           Human-machine intelligence parity by 204
# 668  4.797602e-10           The end of the EU as we know it by 2026?
# 669  3.539051e-09           Will human brain emulation be the first
# 670  6.209189e-08           Will someone born before 2001 live to be
# 671  1.377159e+01           Will SpaceX land people on Mars prior to
# 672  1.341882e-09                             Will the Universe end?
# 673  4.212061e-02           How many cases of end-stage renal diseas
# 674  5.407873e-06           What mean percentage of students will be
# 675  5.528699e-06           What percentage of recent college gradua
# 676  1.331787e-03           What will total enrollment for recent US
# 677  5.392117e-06           How much money will the federal governme
# 678  8.005672e-07           What will the percentage difference betw
# 679  1.180329e-07           Will the nominal salaries of tenured pro
# 680  6.403818e-08           What will the Cohort College Participati
# 681  1.730275e-04           What will the percent difference for inf
# 682  2.974907e-04           What will be the U.S. age-adjusted strok
# 683  2.929577e-09           What will state expenditure from state a
# 684  5.883484e-06           If the current political presidential ad
# 685  2.170529e+00           What will the US Q3 2020 GDP growth rate
# 686  1.082527e-06           How many EU countries will (re)-introduc
# 687  2.489986e-11           How will Sweden and Finland's relative H
# 688  1.214644e-12           What will be the ratio of COVID-19 death
# 689  4.728748e-10           How will Sweden and Finland's relative F
# 690  4.644976e-08           How much transit activity will there be
# 691  2.174662e-08           How much transit activity will there be
# 692  1.568004e-07           How much transit activity will there be
# 693  1.568000e-07           How much transit activity will there be
# 694  1.403158e-07           How much transit activity will there be
# 695  4.973785e-07           How much transit activity will there be
# 696  2.661607e-14           When will U.S. tech workers return to th
# 697  5.312073e-02                 Large scale rioting in US in 2020?
# 698  2.293361e-10           When will the U.S. code "National All-Ha
# 699  9.076978e+00           Will there be a ‘second wave’ of COVID-1
# 700  1.211059e-10           How many deaths due to vaccine-preventab
# 701  1.200745e-10           How many deaths due to vaccine-preventab
# 702  6.875041e-15  Date when a government first requires antibody...
# 703  6.672188e-15  Date when a COVID-19 vaccine is administered t...
# 704  8.735077e-15           How many cases of pediatric multisystem
# 705  1.573111e-15           How many deaths due to pediatric multisy
# 706  1.033707e-15           Will pediatric multisystem inflammatory
# 707  5.049845e-11           When will daily commercial flights excee
# 708  7.507404e-15           When will Amazon offer an in-home diagno
# 709  1.853809e-12           Will any US State mandate COVID-19 diagn
# 710  2.310520e-04   COVID-19 tests administered in the US by June 1:
# 711  5.716179e-09           What will be the list price for a 10-day
# 712  9.086192e-08           If a SARS-CoV-2 vaccine is administered
# 713  2.897130e-05           How many deaths related to COVID-19 will
# 714  8.697961e-05  Will WHO recommend SARS-CoV-2 airborne precaut...
# 715  1.693079e-07           What will be the average overall Global
# 716  5.368839e-02           Will at least 200,000 COVID-19 deaths be
# 717  5.991954e-01  Date when US will suspend travel from the Sche...
# 718  7.017664e-09           Will EA Global London 2020 be cancelled
# 719  3.687066e-10           Will the next peak in COVID-19 hospitali
# 720  3.192362e-14           When will the first antiviral therapy de
# 721  7.401417e+00                       When will Disneyland reopen?
# 722  9.337205e-16           When will an antiviral therapy that demo
# 723  1.652576e-07  Californians that opt in to contact tracing by...
# 724  2.897297e-09           What will the size of Singapore's total
# 725  1.168355e-08           Will at least 400,000 COVID-19 deaths be
# 726  9.839471e-11           What will be the difference between all
# 727  8.088149e-16           How many PHEICs will the WHO declare bet
# 728  2.643764e-13           Will the number of confirmed COVID-19 ca
# 729  1.749802e-05           What portion of in-hospital cases in El
# 730  1.747682e-05           What portion of in-hospital patients wit
# 731  1.267526e-15           Will Australia experience a resurgence o
# 732  1.743891e-05           What will the unemployment rate be in El
# 733  1.858985e-08  Date when Uber will reinstate carpooling optio...
# 734  8.469383e-12           When will Uber reinstate the carpooling
# 735  9.392136e-07           When will Uber reinstate the carpooling
# 736  3.978388e-05           What will be the Airbnb occupancy rate i
# 737  6.863984e-10           When will Uber reinstate the carpooling
# 738  1.999167e-10  Will Stanford hold in-person classes in fall 2...
# 739  7.654821e-08           What will be the relative severity of th
# 740  8.804237e-08  Date when COVID-19 vaccine shows >75% efficacy...
# 741  1.337517e-07           Will the existing Bacillus Calmette-Guer
# 742  7.727105e-08           Will a SARS-CoV-2 vaccine that induces a
# 743  8.124542e-08  Will a RNA COVID-19 vaccine be approved in US ...
# 744  4.754876e-05           Will a SARS-CoV-2 vaccine candidate whos
# 745  9.265540e-08  Date SARS-CoV-2 vaccine will be approved in US...
# 746  1.260118e-07           When will a previously tested SARS-CoV-2
# 747  9.443669e-08  Date when several vaccine candidates are teste...
# 748  1.250770e-07    Completion of SARS-CoV-2 human challenge study:
# 749  1.024840e-07           When will a SARS-CoV-2 vaccine candidate
# 750  1.326315e-07           When will a SARS-CoV-2 vaccine candidate
# 751  1.919097e-07           When will a SARS-CoV-2 vaccine candidate
# 752  4.978497e-07  Date when a COVID-19 vaccine is administered t...
# 753  1.100336e-07           When will a SARS-CoV-2 vaccine candidate
# 754  1.972629e+01  Number of US States mandating protective mask ...
# 755  7.626367e-15  % of re-infections in those who recovered < 12...
# 756  3.561929e-04  % of re-infections in those who recovered < 6 ...
# 757  2.243756e-07           What will unemployment be in the US in 2
# 758  1.551008e-10           How many of the twelve states hit hardes
# 759  1.839292e-14           Will a US Court rule Fox Corporation or
