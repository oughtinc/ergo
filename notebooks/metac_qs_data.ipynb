# %% [markdown]
# # Setup

# %%
# %%capture
# !pip install --progress-bar off poetry
# !pip install --progress-bar off git+https://github.com/oughtinc/ergo.git@5e49ff807fb6b5f032fa1e4c257a8bfa18578d40

# %%
import warnings
warnings.filterwarnings(action="ignore", category=FutureWarning)
warnings.filterwarnings(action="ignore", module="plotnine")

# %%
import pandas as pd
from datetime import datetime

import ergo
from ergo.platforms.metaculus.question import LinearQuestion, LogQuestion, ContinuousQuestion
# Out:
# /Users/brachbach/ought/ergo/ergo/ppl.py:15: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Get questions

# %% [markdown]
# Get all *open* questions on the *main* subdomain.
#
# NOTE: log date questions are excluded because Ergo currently can't handle them

# %%
metaculus = ergo.Metaculus(username="oughtpublic", password="123456", api_domain="www")

# %%
qs = metaculus.get_questions(question_status="open", pages=99999, load_detail=False)

# %%
# The undetailed version of these questions is missing the probability above and below
# the question bounds, which we'd like to have.
# So, fetch the full question data.
for q in qs:
    if q.low_open or q.high_open:
        q.refresh_question()

# %%
exemplar_q_id = 3530

# %%
exemplar_q = metaculus.get_question(exemplar_q_id)

# %%
qs_df = exemplar_q.to_dataframe(qs)

# %% [markdown]
# # Get question metadata

# %% [markdown]
# ## Get all of the metadata already on the question

# %% [markdown]
# Get the field names from the question JSON from Metaculus:

# %%
metaculus_json_fields = list(exemplar_q.data.keys())

# %% [markdown]
# Get the property names from the ContinuousQuestion class:

# %%
def properties(some_class):
    """
    Get all @properties of a class
    """
    class_items = some_class.__dict__.items()
    return [name for (name, value) in class_items if isinstance(value, property)]

# %%
continuous_question_properties = properties(ContinuousQuestion)

# %%
# %%capture
q_fields = metaculus_json_fields + continuous_question_properties

simple_fields = [field for field in q_fields if type(getattr(exemplar_q, field)) in [bool, int, float, str, datetime]]

# This property causes an exception for some reason.
# Didn't seem worth investigating
simple_fields.remove("question_range_width")

for field in simple_fields:
    qs_df[field] = [getattr(q, field, None) for q in qs]

# %% [markdown]
# ## Generate and add more metadata

# %%
def get_p_outside(q):
    if not hasattr(q, "latest_community_percentiles"):
        return None

    # q.latest_community_percentiles is a float for binary questions:
    # https://github.com/oughtinc/ergo/pull/378
    if type(q.latest_community_percentiles) == float:
        return None
    
    return q.latest_community_percentiles["low"] + (1 - q.latest_community_percentiles["high"])

# %%
metadata_columns = {
    "type": lambda q: type(q).__name__,
    "num_boundaries_open": lambda q: int(q.low_open) + int(q.high_open) if hasattr(q, "low_open") else None,
    "question_scale_low": lambda q: q.scale.low if hasattr(q, "scale") else None,
    "question_scale_high": lambda q: q.scale.high if hasattr(q, "scale") else None,
    "question_url": lambda q: f"https://www.metaculus.com{q.page_url}"
}

# %%
for (name, fn) in metadata_columns.items():
    qs_df[name] = [fn(q) for q in qs]

# %% [markdown]
# ## Select and reorder columns

# %% [markdown]
# We have these columns:

# %%
qs_df[qs_df["id"] == exemplar_q_id]
# Out:
#        id                                              title  \
# 259  3530  How many people will die as a result of the 20...
#
#             resolve_time                                             url  \
# 259  2021-01-01 00:00:00  https://www.metaculus.com/api2/questions/3530/
#
#                                               page_url  author status  \
# 259  /questions/3530/how-many-people-will-die-as-a-...  101465      A
#
#                     created_time publish_time           close_time  \
# 259  2020-01-25T04:09:23.208127Z   2020-01-27  2020-11-01 00:00:00
#
#      can_use_powers           last_activity_time  activity  comment_count  \
# 259            True  2020-06-17T15:51:31.488705Z  4.083308            231
#
#      votes                           title_short  user_vote  \
# 259    146  COVID-19 related deaths before 2021:          0
#
#      user_community_vis author_name anon_prediction_count last_read low_open  \
# 259                 0.0        None                  None      None     True
#
#     high_open has_predictions  \
# 259      True            True
#
#                                             plot_title         type  \
# 259  How many people will die as a result of the 20...  LogQuestion
#
#      num_boundaries_open p_outside question_range_min question_range_max  \
# 259                  2.0      None                200          100000000
#
#                                           question_url
# 259  https://www.metaculus.com/questions/3530/how-m...

# %% [markdown]
# Select all the ones that might plausibly be useful, and put them in a reasonable order:

# %%
qs_df = qs_df[[
    "id",
    "title",
    "question_url",
    "type",
    "num_boundaries_open",
    "low_open",
    "high_open",
    "p_outside",
    "question_scale_low",
    "question_scale_high",
    "anon_prediction_count",
    "last_activity_time",
    "votes",
    "comment_count",
    "created_time",
    "publish_time",
    "close_time",
    "resolve_time",
    "author_name",
    "last_read",
    "has_predictions",
    "activity",
    "title_short"
]]

# %%
qs_df[qs_df["id"] == exemplar_q_id]
# Out:
#        id                                              title  \
# 259  3530  How many people will die as a result of the 20...
#
#                                           question_url         type  \
# 259  https://www.metaculus.com/questions/3530/how-m...  LogQuestion
#
#      num_boundaries_open low_open high_open p_outside question_range_min  \
# 259                  2.0     True      True      None                200
#
#     question_range_max anon_prediction_count           last_activity_time  \
# 259          100000000                  None  2020-06-17T15:51:31.488705Z
#
#      votes  comment_count                 created_time publish_time  \
# 259    146            231  2020-01-25T04:09:23.208127Z   2020-01-27
#
#               close_time         resolve_time author_name last_read  \
# 259  2020-11-01 00:00:00  2021-01-01 00:00:00        None      None
#
#     has_predictions  activity                           title_short
# 259            True  4.083308  COVID-19 related deaths before 2021:

# %% [markdown]
# ## Explanations of some important fields
# - `low_open`: Is the lower boundary of the question open? (only applies to ContinuousQuestions)
# - `high_open`: Is the upper boundary of the question open? (only applies to ContinuousQuestions)
# - `p_outside`: How much of the total probability mass of the community prediction is outside the question range? (only applies to ContinuousQuestions)
# - `anon_prediction_count`: Seems to be a proxy for the number of predictions. See "Data notes" below.
# - `last_activity_time`: Seems to be a quick proxy for the time of the last prediction on the question. See "Data notes" below.
# - `comment_count`: How many comments have been left on this question?
# - `created_time`: When did the author of the question create it? (I think)
# - `publish_time`: When was the question published to all Metaculus users?
# - `close_time`: After what time are predictions on this question no longer allowed?
# - `resolve_time`: When can the question be resolved, i.e. when will the answer be known?

# %% [markdown]
# ## Data notes:
# 1. `anon_prediction_count` is the closest thing I could find to a count of number of predictions, but I'm not really sure how it relates to the number of predictions. In my testing:
#     1. It seems to always be the same as the length of `prediction_timeseries`
#     2. It seems to be correlated with something about the number of predictions shown. E.g.
#         1. it's 101 for this question where the community prediction is shown: https://www.metaculus.com/questions/3530/how-many-people-will-die-as-a-result-of-the-2019-novel-coronavirus-covid-19-before-2021/.
#         2. While it's 0 for this question where the community prediction is not shown yet: https://www.metaculus.com/questions/4614/when-will-directly-removing-carbon-dioxide-from-the-atmosphere-be-economically-feasible/
#     3. I couldn't get it to increment. I tried:
#         1. making a new prediction with an account that had already predicted on the question
#         2. making a prediction with an account that had never predicted on that question before.
# 2.`last_activity_time` seems like the most obvious easy proxy for when the most recent prediction was made. However, I'm not sure how reliable it is.
#     1. It did not update when I made a new prediction from an account that had already predicted on the question previously
#     2. It may update when people leave comments or at other times
#     3. Alternatively, we could use the last time from the `prediction_timeseries`, but that also doesn't seem to update every time someone makes a prediction
# 3. To get the datetime of the last posted comment, I think we'd need to retrieve it from a separate API (prob at least 30 min of work, maybe more like hours), so I haven't tried
# 4. Log date questions are excluded here because Ergo can't handle them yet.

# %% [markdown]
# # View data

# %% [markdown]
# ## Export as csv
#
# (For use when running locally in `ergo/notebooks`)

# %%
# qs_df.to_csv("../ergo/contrib/metac_qs_data/metac_qs_data.csv", index=False, float_format='%.20f')

# %% [markdown]
# A version of this CSV is uploaded as a [Google Sheet](https://docs.google.com/spreadsheets/d/1Aii_IkUTiJH6t14n2lhwhu4PJJjlTz6X5vdEi5gPGa0/edit#gid=1305569144).

# %% [markdown]
# ## View all questions

# %%
qs_df
# Out:
#        id                                              title  \
# 0    4637            Will the S&P 500 close higher for 2020?
# 1    4627   Will US forces shoot unarmed protesters in 2020?
# 2    4527  Will the S&P 500 hit 10,000 points by the end ...
# 3    4614  When will directly removing carbon dioxide fro...
# 4    4622  How many more Starship prototypes will be dest...
# 5    4596  What will the percentage difference between fu...
# 6    4646  What will total enrollment for recent US high ...
# 7    4628  Will one of GiveWell's 2019 top charities be e...
# 8    4607  Will California Assembly Bill 3155 be chaptere...
# 9    4408  Will Apple announce plans to make ARM-based Ma...
# 10   4615  What annual real return will the S&P 500 reali...
# 11   4586  If Biden becomes president, will the sentencin...
# 12   4609  If President Trump loses the 2020 election, wi...
# 13   4630  Will Metaculus Inc. host a prediction market p...
# 14   4603  What will the US Q3 2020 GDP growth rate be, a...
# 15   4617           Will 2020 be the warmest year on record?
# 16   4584  What % of money held in all US DAFs will be ex...
# 17   4588  When will SpaceX's Starship carry a human to o...
# 18   4608  In 2024, what percentage of surveyed Americans...
# 19   4585  What annual real return will the global stock ...
# 20   4606                      When will we have a new Pope?
# 21   4055      Will the first AGI be based on deep learning?
# 22   4554  Will more than one entrant achieve a perfect s...
# 23   4544  Will there be fewer Kea parrots in 2030 than t...
# 24   4050  What will the maximum world real GDP growth in...
# 25   4319  Longbets series: By 2040 will the percentage o...
# 26   4249  When will there be a vegan cheese indistinguis...
# 27   4219  Will large scale solar radiation management be...
# 28   4443  When will China surpass the United States econ...
# 29   4572  How much transit activity will there be in the...
# 30   4568  How much transit activity will there be in New...
# 31   4569  How much transit activity will there be in New...
# 32   4573  How much transit activity will there be in the...
# 33   4570  How much transit activity will there be in New...
# 34   4574  How much transit activity will there be in the...
# 35   4451  When will the first 100 million digit prime nu...
# 36   4518  How many billions of parameters will the large...
# 37   4562  Will the artist who performs 2020’s UK Christm...
# 38   4564  Will a TikTok user hit 100m followers by the e...
# 39   4556  Will 3Blue1Brown begin a new video series in t...
# 40   4559  Will the next winner of the Booker Prize be fe...
# 41   4561  Will J.K. Rowling’s “The Ickabog” reach #1 on ...
# 42   4563             Will 2020’s UK Christmas #1 be a joke?
# 43   4555  Will Trump's pants catch fire on at least five...
# 44   4511  How long would humanity take to rebound from a...
# 45   4565  Will more than five of the ten highest grossin...
# 46   4571  How much transit activity will there be in the...
# 47   4567  How much transit activity will there be in New...
# 48   4524  Will the US conduct a nuclear test explosion b...
# 49   4444  What will be the highest value of the U.S. Pri...
# 50   3725  When will a private fusion company first repor...
# 51   4290  Will NAD+ boosters be shown in a systematic re...
# 52   4536        Will the US see widespread rioting in 2020?
# 53   4516  Will California Senate Bill 902 be chaptered i...
# 54   4433  If Biden becomes president, will there be an e...
# 55   4441           When will be the next "Great Power" war?
# 56   1059  Before 2051, will a meteor cause more injuries...
# 57   4121         Will Italy leave the Eurozone before 2023?
# 58   3913  When will a vaccine for HIV be administered to...
# 59   4440  What rank will the United States be on the ine...
# 60   4439          When will North Korea become a democracy?
# 61   4446  How many structures will be destroyed by wildf...
# 62   4286  When will Chicago CTA subway cars reopen for n...
# 63   4425  Will Israel annex  the Jordan Valley in the We...
# 64   4442  What will be the gross receipts of the SENS Re...
# 65   4418  What is the greatest number of people who, for...
# 66   4403  Will Amazon ($AMZN) make a public offer to acq...
# 67   4429  By 1 January 2067, medical interventions for h...
# 68   4414  Will Elon Musk's baby's name, X Æ A - 12, turn...
# 69   4409   Will one of the first AGI claim to be conscious?
# 70   4415  Will American Airlines file for bankruptcy pro...
# 71   3657  If a single-payer healthcare system is adopted...
# 72   4125  What will be the first year during which most ...
# 73   2711  Will a Guaranteed Minimum Income introduced in...
# 74   4119   What will be the S&P 500 end-of-day low in 2020?
# 75   4235  When will multi-modal ML out-perform uni-modal...
# 76   4237  How many months of 2020 will be declared "eart...
# 77   4390  What will be the lowest cost per kilogram, in ...
# 78   4265  How much exercise can you do before it starts ...
# 79    593  If alien life is discovered in the Solar Syste...
# 80   4364  When will the US national debt reach $50 trill...
# 81   4354  Will Joe Biden be the Democratic Party nominee...
# 82   4127  Will a member of the Trump family be the Repub...
# 83   4183  How many deaths related to COVID-19 will be re...
# 84   3277  What will be the average overall Global Health...
# 85   4207  Will at least 200,000 COVID-19 deaths be repor...
# 86   1444  Will an openly LGBTQ person be elected Preside...
# 87    953  Will Mike Pence be elected president of the Un...
# 88    480  If chess is solved before 2080, must perfect p...
# 89   4349  Will the Harvard endowment be larger in 2119 t...
# 90   4328  Will a total sum amounting to at least 10% of ...
# 91   4264  How many years after the silver Turing Test is...
# 92   4110  Assuming some humans are alive, what will be t...
# 93   4291  When will the suspension of incoming travel to...
# 94   4334  If chess is solved before 2080, must perfect p...
# 95    804               Will question 1000 resolve positive?
# 96   4332  How much will GiveWell guess it will cost to g...
# 97   4051  Will Alcor offer the use of a fixative during ...
# 98    952  In which month will there first be 20,000 new ...
# 99   4101  If Donald Trump is reelected president, what w...
# 100  4123  After an AGI is created, how many months will ...
# 101  4318  Will EA Global London 2020 be cancelled or res...
# 102  4333  What will be the Democracy Index of the United...
# 103  3613  How many posts will there be on the Effective ...
# 104  4209  When will a human chess player reach a FIDE ra...
# 105  4061  Will Any Major AI Company Commit to an AI Wind...
# 106  4053  What will be the Alexa Traffic Rank for Metacu...
# 107  3648  Longbets series: By 2029 will a computer have ...
# 108  3647  Longbets series: By 2025 will the scientific e...
# 109  4232  When will AI out-perform humans on argument re...
# 110  4116                       When will Disneyland reopen?
# 111  4314  What will the magnitude of most severe earthqu...
# 112  4313  Will (at least one) magnitude 6.0 or greater e...
# 113  4052  If cryonics is at some point offered for free,...
# 114  4057  What will be the sentiment of Metaculus users ...
# 115  4224  Will Stephen Wolfram or his co-authors, Jonath...
# 116  4118  Will there be a positive transition to a world...
# 117  4078  What will the size of Singapore's total foreig...
# 118  4171  How much karma will the top LessWrong post in ...
# 119  4048  How many cents will it cost a typical consumer...
# 120  4220  Will Wayne Hsiung be elected mayor of Berkeley...
# 121  4047  What will the top GPU score be on Passmark on ...
# 122  4215  What will be the real world GDP on the year AG...
# 123  4046  What will the top CPU score be on Passmark on ...
# 124  3999  What will the peak population of Antarctica be...
# 125  3840  When will Nintendo release a console capable o...
# 126  3618     When will the United States admit a new state?
# 127  4097  Will China Oceanwide Holdings Group Co., Ltd. ...
# 128  3812  Will Valve release a game before 2030 with 3 i...
# 129  3777  Will reducing wild animal suffering be a mains...
# 130  4083  What will be the relative severity of the next...
# 131  3629  Will the National Popular Vote Interstate Comp...
# 132  4036  What will China's unemployment rate be for Q1 ...
# 133  4094  How many years will caloric restriction be dem...
# 134  4043   When will OpenAI unveil their secret AI project?
# 135  3125  Will the United States continue to be among th...
# 136  4037  Will a sitting US president not seek reelectio...
# 137  4028  What proportion of Senate Democratic incumbent...
# 138  4027  What proportion of Senate Republican incumbent...
# 139  4026  What proportion of House Republican incumbents...
# 140  3125  Will the United States continue to be among th...
# 141  4029  What proportion of House Democratic incumbents...
# 142  4066  When will a SARS-CoV-2 vaccine candidate that ...
# 143  3868  If there is a WW3, what latitude will it start...
# 144  3867  If there is a WW3, what longitude will it star...
# 145  4032       What will unemployment be in the US in 2021?
# 146  4033          What will inflation be in the US in 2021?
# 147  4035       Will the US see mass price controls in 2021?
# 148  4054  How many reviews will Toby Ord's book The Prec...
# 149  4034  By 2030, will C. elegans be uploaded to the sa...
# 150  4017  When will the US unemployment rate fall to 4% ...
# 151  4013  Will the next US recession turn into a depress...
# 152  3987  What will be the peak unemployment rate in the...
# 153  3972  What will the US Q2 2020 GDP growth rate be, a...
# 154  3856  Will at least 1 million COVID-19 deaths be rep...
# 155  3900            Will the US see a massive riot in 2020?
# 156  3896  Will most UK schools reopen in time for the 20...
# 157  3858          Will the USD still reign supreme by 2050?
# 158  3932  Will Harvard University open classes on Septem...
# 159  3912  Will a recession cause "suicides by the thousa...
# 532  1628  What will be the longest verified human lifesp...
# 533  1626  Before 1 January 2050, will any human cryonica...
# 534  1618              Is the Zuma satellite still in orbit?
# 535  1620  What will be the heaviest payload put into LEO...
# 536  1604  Ragnarök Question Series: if a global climate ...
# 537  1600  The Top500's total sum in 2030 as a multiple o...
# 538  1598            Will Elon Musk (attempt to) go to Mars?
# 539  1596  What year will the 2˚C climate threshold be cr...
# 540  1591  Will the impact of the Effective Altruism move...
# 541  1585  Ragnarök Question Series: if a nuclear catastr...
# 542  1537          When will the first cloned human be born?
# 543  1568  Will we detect an exoplanet atmosphere with >5...
# 544  1579  Will China be the World's largest economy in a...
# 545  1574              What will the World's GDP be in 2028?
# 546  1576        Fewer than 375M in extreme poverty by 2030?
# 547  1558  The Rise and Fall of the Banana: Will the curr...
# 548  1552  Is non-theism (atheists and agnostics) growing...
# 549  1536  Will a third LIGO detector be built in India b...
# 550  1540  How much less global warming if the US resumes...
# 551  1538  Will Metaculus predict that artificial intelli...
# 552  1539                      3.6°C global warming by 2100?
# 553  1535  Will most protons that currently make up Earth...
# 554  1088  When will the last member of our species, homo...
# 555  1085      When will the student loan debt bubble "pop"?
# 556  1519  When will the total number of people who have ...
# 557  1515  Do humans have functionally important neurogen...
# 558  1492  What will be Top500's #1 performing supercompu...
# 559  1503  How many NASA "space launch system" (SLS) laun...
# 560  1500  Ragnarök Question Series: If a global catastro...
# 561  1501  Ragnarök Question Series: If a global catastro...
# 562  1494  Ragnarök Question Series: If a global catastro...
# 563  1502  Ragnarök Question Series: If a global catastro...
# 564  1495  Ragnarök Question Series: If a global catastro...
# 565  1493  Ragnarök Question Series: By 2100 will the hum...
# 566  1481  When will either the Democratic or Republican ...
# 567  1480  Will any intelligent living being (human desce...
# 568  1482  What percentage of Americans will be considere...
# 569  1476       Will NASA land people on Mars prior to 2030?
# 570  1469      Will we know what Dark Matter is before 2050?
# 571  1468      Will Xi Jinping keep leading China past 2022?
# 572  1457  Will Angela Merkel remain chancellor after the...
# 573  1454  A freer China? Chinese political rights and ci...
# 574  1434  When will India send their first own astronaut...
# 575  1435  When will the longest spaceflight of any one p...
# 576  1432  Will humans have a sustainable off-world prese...
# 577  1433  Will the fraction of American 18-24 year-olds ...
# 578  1416                   When will one TeraFlOPS cost $1?
# 579  1408  Does P = NP? Informally: If the solution to a ...
# 580  1402  Will Parker Solar Probe survive its 24 loops a...
# 581  1343  Drake's Equation Question Set: for how many ye...
# 582  1385  Qualia Research Institute Question Series: Wil...
# 583  1394                      Will AI progress surprise us?
# 584  1342  Drake's Equation Question Set: What fraction o...
# 585  1339  Drake's Equation Question Set: what is the ave...
# 586  1384  Qualia Research Institute Question Series: Wil...
# 587  1341  Drake's Equation Question Set: on what fractio...
# 588  1340  Drake's Equation Question Set: on what fractio...
# 589  1338  Drake's Equation Question Set: what fraction o...
# 590  1061         Will there be a 9 foot tall human by 2075?
# 591  1348  Will a mission to land a spacecraft on Europa ...
# 592  1332  Will global malaria mortality rates be reduced...
# 593  1337  Drake's Equation Question Set: 1st Parameter R...
# 594  1321                 Will Ray Kurzweil be proven right?
# 595  1139  Will a scientific mission to the outer solar s...
# 596  1090  Will we get through the 21st century without a...
# 597  1100         Will Trump be reelected president in 2020?
# 598  1079       Will Elon Musk (eventually) lose his appeal?
# 599  1058  Will humanity (essentially) run out of at leas...
# 600  1052  Will there be a city on Earth with a populatio...
# 601  1056  How long will the Great Pyramids be recognizable?
# 602  1011  Will Roe v. Wade be formally overturned within...
# 603  1002  Any progress in human lifespan enhancement by ...
# 604   943  When will we get the last communication from V...
# 605   980  Will Tesla become the largest car company in t...
# 606   981  Will cannabis be removed from Schedule I of th...
# 607   974  What will be the value of the (herein describe...
# 608   968  Will cost-adjusted IT technology be worse than...
# 609   969     When will commercial supersonic flight return?
# 610   957    Will Donald Trump serve time in jail or prison?
# 611   915  Will we discover clear evidence of proton deca...
# 612   917  Will a space elevator successfully be built by...
# 613   916  Will another 9/11 on U.S. soil be prevented at...
# 614   899  Will the world's richest person in 2033 have a...
# 615   841                      Will Metaculus exist in 2030?
# 616   824  Will a practical nuclear fusion reactor first ...
# 617   808  Will Europa be the first place humanity will d...
# 618   797  Will Puerto Rico become a US state prior to 2035?
# 619   737         Will SpaceX land anything on Mars by 2030?
# 620   736  Will there be a complete 4 year interval in wh...
# 621   735           When will there be a mile-high building?
# 622   686  Will a human made spaceship enter the Venusian...
# 623   684  By 2025 will someone be able to hold his/her b...
# 624   665                          Kessler syndrome by 2050?
# 625   658     Will we reach the island of stability by 2050?
# 626   600  Will a sample of negative energy be produced b...
# 627   614             Will there be a Vegan Country by 2100?
# 628   610  Will our current peace be shorter than the Pax...
# 629   604  Will gravitational waves from the merger of su...
# 630   606     Answer to signal broadcast into space by 2045?
# 631   605                   How much global warming by 2100?
# 632   594            Increased off-world population in 2050?
# 633   587                          World Population in 2050?
# 634   570          A major United States earthquake by 2023?
# 635   585                        2˚C global warming by 2100?
# 636   579           Will VR or AR Headsets dominate by 2025?
# 637   578                    Will humans go extinct by 2100?
# 638   523  Resolution of the Density Conjecture for Newto...
# 639   512  Will an AI system do credibly well on a full m...
# 640   513  Will the first commercial hyperloop system be ...
# 641   504  How many subscribers will Netflix have by Augu...
# 642   492  With an international nuclear weapons ban in p...
# 643   491  Will China achieve its Paris Climate Agreement...
# 644   489  Will the European Union meet its 2030 targets ...
# 645   477  Efficacy confirmation of a new Alzheimer's tre...
# 646   455  If you die today and get cryonically frozen, w...
# 647   397                                  Robocup Challenge
# 648   384         Human-machine intelligence parity by 2040?
# 649   375           The end of the EU as we know it by 2026?
# 650   372  Will human brain emulation be the first succes...
# 651   353      Will someone born before 2001 live to be 150?
# 652   349     Will SpaceX land people on Mars prior to 2030?
# 653   161                             Will the Universe end?
#
#                                           question_url                type  \
# 0    https://www.metaculus.com/questions/4637/will-...      BinaryQuestion
# 1    https://www.metaculus.com/questions/4627/will-...      BinaryQuestion
# 2    https://www.metaculus.com/questions/4527/will-...      BinaryQuestion
# 3    https://www.metaculus.com/questions/4614/when-...  LinearDateQuestion
# 49   https://www.metaculus.com/questions/4444/what-...      LinearQuestion
# 50   https://www.metaculus.com/questions/3725/when-...  LinearDateQuestion
# 51   https://www.metaculus.com/questions/4290/will-...      BinaryQuestion
# 52   https://www.metaculus.com/questions/4536/will-...      BinaryQuestion
# 53   https://www.metaculus.com/questions/4516/will-...      BinaryQuestion
# 54   https://www.metaculus.com/questions/4433/if-bi...      BinaryQuestion
# 55   https://www.metaculus.com/questions/4441/when-...  LinearDateQuestion
# 56   https://www.metaculus.com/questions/1059/befor...      BinaryQuestion
# 57   https://www.metaculus.com/questions/4121/will-...      BinaryQuestion
# 58   https://www.metaculus.com/questions/3913/when-...  LinearDateQuestion
# 59   https://www.metaculus.com/questions/4440/what-...      LinearQuestion
# 60   https://www.metaculus.com/questions/4439/when-...  LinearDateQuestion
# 61   https://www.metaculus.com/questions/4446/how-m...         LogQuestion
# 62   https://www.metaculus.com/questions/4286/when-...  LinearDateQuestion
# 63   https://www.metaculus.com/questions/4425/will-...      BinaryQuestion
# 64   https://www.metaculus.com/questions/4442/what-...         LogQuestion
# 65   https://www.metaculus.com/questions/4418/what-...         LogQuestion
# 66   https://www.metaculus.com/questions/4403/will-...      BinaryQuestion
# 67   https://www.metaculus.com/questions/4429/by-1-...      BinaryQuestion
# 68   https://www.metaculus.com/questions/4414/will-...      BinaryQuestion
# 69   https://www.metaculus.com/questions/4409/will-...      BinaryQuestion
# 70   https://www.metaculus.com/questions/4415/will-...      BinaryQuestion
# 71   https://www.metaculus.com/questions/3657/if-a-...      BinaryQuestion
# 72   https://www.metaculus.com/questions/4125/what-...  LinearDateQuestion
# 73   https://www.metaculus.com/questions/2711/will-...      BinaryQuestion
# 74   https://www.metaculus.com/questions/4119/what-...      LinearQuestion
# 75   https://www.metaculus.com/questions/4235/when-...  LinearDateQuestion
# ...
# 374           In the year ending November 2nd, 2020, w
# 375           Will total funding in longevity startups
# 376           In the year ending in November 2nd, 2020
# 377           By November 2020 will a prediction made
# 378           By November 2nd, 2020, will Twitter temp
# 379           By November 2nd, 2020, will the ten citi
# 380           In the year ending in November 2nd, 2020
# 381           Will Israel be the fourth country to sof
# 382           How many billions of broiler-type chicks
# 383           In what year will the total number of he
# 384           How many billions of hen eggs will be pr
# 385           Will Robert Caro's fifth and final volum
# 386           What will be the U.S. average weekly hou
# 387           Will US Non-Overseas Contingency operati
# 388           Will alien technosignatures be detected
# 389           What will the average global atmospheric
# 390           Will the first extraterrestrial life-for
# 391           Will Turkey be a NATO member continuousl
# 392           What will the upper limit in the IPCC's
# 393              Who will first land a person on Mars?
# 394           What will the upper limit in the IPCC's
# 395           When will at least 20 U.S. states legali
# 396           When will beef for human consumption, fr
# 397           Will no non-test nuclear weapons be deto
# 398           If DNA alterations continue to require a
# 399           When will 100 people or more be in space
# 400           When will the milk of cows whose DNA is
# 401           What will be the labor force participati
# 402           Will WeWork file for bankruptcy protecti
# 403           By 2030, how many people will have ever
# 404           When will a genetic change cease to trig
# 405           If DNA alterations continue to require F
# 406           How many commercial cattle, in millions,
# 407           When will a Bering Strait crossing be co
# 408           What will be the labor force participati
# 409           How much will be estimated to have been
# 410           Will Oregon vote to legalize medical use
# 411           Will Extinction Rebellion, or a splinter
# 412           How many commercial cattle, in millions,
# 413           How many publicly traded U.S.- or EU-bas
# 414           Will a new land speed record be set by 2
# 415           Will Mars have a permanent population of
# 416           When will a discernible, coordinated Bit
# 417                 Will the Mars 2020 helicopter fly?
# 418           What will the listing price of an Imposs
# 419           How many commercial cattle, in millions,
# 420           Will General Electric (GE) file for chap
# 421           How much will the total U.S. plant-based
# 422           How much will the total U.S. plant-based
# 423           What will the lowest retail price, in US
# 424           What will the lowest retail price, in US
# 425           What will the U.S. market for plant-base
# 426           What will the U.S. market for plant-base
# 427           When will a restaurant first serve clean
# 428           When will a supermarket sell a product m
# 429           When will a supermarket sell a product m
# 430           What is the probability that Gore will d
# 431           When will a restaurant first serve clean
# 432           How many Starlink satellites will be in
# 433           How much revenue will the U.S. market fo
# 434           How much revenue will the U.S. market fo
# 435           When will there be a publicly listed cle
# 436           How many months till at least three, bil
# 437           When will there be a publicly listed cle
# 438           When will the first clean meat company b
# 439           Bitcoin Lightning Network Capacity in BT
# 440           How many hours will the average American
# 441           When will the first organ from a non-pri
# 442           When will any country have a life expect
# 443           Will wildfires destroy a total exceeding
# 444           When will the median Hongkonger be merel
# 445           When will the first human baby from stem
# 446           Will the significant discrepancies in Hu
# 447           When will the James Webb Space Telescope
# 448           If there is a biotechnological or bioeng
# 449           Will the eventual consensus explanation
# 450           In 2029, how many small firearms per cap
# 451           How many biological humans will be alive
# 452           When will Elon Musk have any device, suc
# 453           How many predictions will have been made
# 454           When will the global adult literacy rate
# 455           Will the number of deaths from antibioti
# 456           If and when the first whole human brain
# 457           Will there be another case of smallpox b
# 458           In 2029, will the US have fewer nuclear
# 459           If the US does not pursue nuclear disarm
# 460           When will NASA's SLS first launch a pers
# 461           Will the UK housing market crash before
# 462           Is the halting problem for the Collatz P
# 463           If a whole human brain is successfully e
# 464           If there is an artificial intelligence c
# 465                    Is the Collatz Conjecture true?
# 466           Will NASA's SLS launch a person to the M
# 467           Will no non-test nuclear weapons be deto
# 468           Will the Token Taxonomy Act of 2019 beco
# 469           By 2025, will laws be in place requiring
# 470           At the end of 2023, will Animal Charity
# 471           How much will GiveWell guess it will cos
# 472           Will Nigel Farage become Prime Minister
# 473           Will Apollo 10's Lunar Module be recover
# 474           Will the text of the Voynich manuscript
# 475           Will the SOO Green Renewable Rail projec
# 476           Will there be more people with HIV/AIDS
# 477           Will the International Thermonuclear Exp
# 478           Will the United States fulfill its goal
# 479           Will Volkswagen Group produce fewer than
# 480           Will World GDP grow every year until 202
# 481           Will Germany fail to meet their coal com
# 482           A tech boom to surpass the dotcom bubble
# 483           Will the Square Kilometre Array (SKA) be
# 484           What will the necessary computational po
# 485           When will image recognition be made robu
# 486           When the first company reaches a $2 tril
# 487           When the first company reaches a $10 tri
# 488           Will Nigeria's population exceed 400 mil
# 489     Months possible recession in the US will last:
# 490           Will the US set a new annual GDP growth
# 491           Will any Member State leave the Eurozone
# 492           When will Haiti become an upper middle-i
# 493           Will synthetic biological weapons infect
# 494           Will any country's military expenditure
# 495           Will any of the 20 most valuable public
# 496           When will North Korea have a McDonald's?
# 497           When will India become a World Bank high
# 498           When will a DUI be overruled or turned d
# 499           Will Scotland leave the United Kingdom b
# 500           What will the atmospheric CO2 concentrat
# 501           Will a Metaculus user report from space
# 502           When will Xi Jinping leave power in Chin
# 503           Will there be a 'World War Three' before
# 504           Ragnarök Question Series: if a global bi
# 505           Ragnarök Question Series: if an artifici
# 506           How many people will be estimated to hav
# 507           Will there be another VEI level six (or
# 508           Will there be a major nuclear or radiolo
# 509           Will Emmanuel Macron be re-elected Presi
# 510           If the James Webb Space Telescope is lau
# 511           Will the Kármán Line be changed before 2
# 512           Will George R. R. Martin die before the
# 513           When will the next vacancy arise for a J
# 514           What will be the greatest velocity attai
# 515           When will the 10,000th human reach space
# 516           Will the USA's Labor Force Participation
# 517           Will any asteroid or comet have been min
# 518           Will the Second Amendment to the United
# 519           Will functional respirocytes be used suc
# 520           Before 2025, will an asteroid or comet e
# 521           A breakthrough in accurately predicting
# 522           Will it once again be possible to travel
# 523           By 1 January 2050, will it be possible t
# 524           Will lab-grown complex vital organs be u
# 525           Will US income inequality increase by 20
# 526           Will Alex Jones ever hold high Federal o
# 527           How many electoral college votes will Do
# 528           Will Cuba still be a communist state in
# 529           Will a mouse be confirmed to have lived
# 530           Will a senolytic therapy be approved for
# 531           What percentage of US residents will be
# 532           What will be the longest verified human
# 533           Before 1 January 2050, will any human cr
# 534              Is the Zuma satellite still in orbit?
# 535           What will be the heaviest payload put in
# 536           Ragnarök Question Series: if a global cl
# 537           The Top500's total sum in 2030 as a mult
# 538            Will Elon Musk (attempt to) go to Mars?
# 539           What year will the 2˚C climate threshold
# 540           Will the impact of the Effective Altruis
# 541           Ragnarök Question Series: if a nuclear c
# 542           When will the first cloned human be born
# 543           Will we detect an exoplanet atmosphere w
# 544           Will China be the World's largest econom
# 545              What will the World's GDP be in 2028?
# 546           Fewer than 375M in extreme poverty by 20
# 547           The Rise and Fall of the Banana: Will th
# 548           Is non-theism (atheists and agnostics) g
# 549           Will a third LIGO detector be built in I
# 550           How much less global warming if the US r
# 551           Will Metaculus predict that artificial i
# 552                      3.6°C global warming by 2100?
# 553           Will most protons that currently make up
# 554           When will the last member of our species
# 555           When will the student loan debt bubble "
# 556           When will the total number of people who
# 557           Do humans have functionally important ne
# 558           What will be Top500's #1 performing supe
# 559           How many NASA "space launch system" (SLS
# 560           Ragnarök Question Series: If a global ca
# 561           Ragnarök Question Series: If a global ca
# 562           Ragnarök Question Series: If a global ca
# 563           Ragnarök Question Series: If a global ca
# 564           Ragnarök Question Series: If a global ca
# 565           Ragnarök Question Series: By 2100 will t
# 566           When will either the Democratic or Repub
# 567           Will any intelligent living being (human
# 568           What percentage of Americans will be con
# 569           Will NASA land people on Mars prior to 2
# 570           Will we know what Dark Matter is before
# 571           Will Xi Jinping keep leading China past
# 572           Will Angela Merkel remain chancellor aft
# 573           A freer China? Chinese political rights
# 574           When will India send their first own ast
# 575           When will the longest spaceflight of any
# 576           Will humans have a sustainable off-world
# 577           Will the fraction of American 18-24 year
# 578                   When will one TeraFlOPS cost $1?
# 579           Does P = NP? Informally: If the solution
# 580           Will Parker Solar Probe survive its 24 l
# 581           Drake's Equation Question Set: for how m
# 582           Qualia Research Institute Question Serie
# 583                      Will AI progress surprise us?
# 584           Drake's Equation Question Set: What frac
# 585           Drake's Equation Question Set: what is t
# 586           Qualia Research Institute Question Serie
# 587           Drake's Equation Question Set: on what f
# 588           Drake's Equation Question Set: on what f
# 589           Drake's Equation Question Set: what frac
# 590           Will there be a 9 foot tall human by 207
# 591           Will a mission to land a spacecraft on E
# 592           Will global malaria mortality rates be r
# 593           Drake's Equation Question Set: 1st Param
# 594                 Will Ray Kurzweil be proven right?
# 595           Will a scientific mission to the outer s
# 596           Will we get through the 21st century wit
# 597         Will Trump be reelected president in 2020?
# 598           Will Elon Musk (eventually) lose his app
# 599           Will humanity (essentially) run out of a
# 600           Will there be a city on Earth with a pop
# 601           How long will the Great Pyramids be reco
# 602           Will Roe v. Wade be formally overturned
# 603           Any progress in human lifespan enhanceme
# 604           When will we get the last communication
# 605           Will Tesla become the largest car compan
# 606           Will cannabis be removed from Schedule I
# 607           What will be the value of the (herein de
# 608           Will cost-adjusted IT technology be wors
# 609           When will commercial supersonic flight r
# 610           Will Donald Trump serve time in jail or
# 611           Will we discover clear evidence of proto
# 612           Will a space elevator successfully be bu
# 613           Will another 9/11 on U.S. soil be preven
# 614           Will the world's richest person in 2033
# 615                      Will Metaculus exist in 2030?
# 616           Will a practical nuclear fusion reactor
# 617           Will Europa be the first place humanity
# 618           Will Puerto Rico become a US state prior
# 619           Will SpaceX land anything on Mars by 203
# 620           Will there be a complete 4 year interval
# 621           When will there be a mile-high building?
# 622           Will a human made spaceship enter the Ve
# 623           By 2025 will someone be able to hold his
# 624                          Kessler syndrome by 2050?
# 625           Will we reach the island of stability by
# 626           Will a sample of negative energy be prod
# 627             Will there be a Vegan Country by 2100?
# 628           Will our current peace be shorter than t
# 629           Will gravitational waves from the merger
# 630           Answer to signal broadcast into space by
# 631                   How much global warming by 2100?
# 632            Increased off-world population in 2050?
# 633                          World Population in 2050?
# 634           A major United States earthquake by 2023
# 635                        2˚C global warming by 2100?
# 636           Will VR or AR Headsets dominate by 2025?
# 637                    Will humans go extinct by 2100?
# 638           Resolution of the Density Conjecture for
# 639           Will an AI system do credibly well on a
# 640           Will the first commercial hyperloop syst
# 641           How many subscribers will Netflix have b
# 642           With an international nuclear weapons ba
# 643           Will China achieve its Paris Climate Agr
# 644           Will the European Union meet its 2030 ta
# 645           Efficacy confirmation of a new Alzheimer
# 646           If you die today and get cryonically fro
# 647                                  Robocup Challenge
# 648           Human-machine intelligence parity by 204
# 649           The end of the EU as we know it by 2026?
# 650           Will human brain emulation be the first
# 651           Will someone born before 2001 live to be
# 652           Will SpaceX land people on Mars prior to
# 653                             Will the Universe end?
