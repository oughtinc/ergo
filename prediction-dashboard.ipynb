# %% [markdown]
# <a href="https://colab.research.google.com/github/oughtinc/ergo/blob/notebooks-readme/prediction-dashboard.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Setup

# %% [markdown]
# Installation:

# %%
# !pip install --quiet poetry  # Fixes https://github.com/python-poetry/poetry/issues/532
# !pip install --quiet git+https://github.com/oughtinc/ergo.git@dashboardv3
# !pip install --quiet pendulum seaborn
# Out:
#      |████████████████████████████████| 225kB 2.8MB/s
#      |████████████████████████████████| 92kB 6.9MB/s
#      |████████████████████████████████| 61kB 6.4MB/s
#      |████████████████████████████████| 112kB 9.1MB/s
#      |████████████████████████████████| 61kB 6.5MB/s
#      |████████████████████████████████| 2.7MB 9.3MB/s
#   Building wheel for pyrsistent (setup.py) ... done
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
#      |████████████████████████████████| 61kB 2.0MB/s
#      |████████████████████████████████| 51kB 7.0MB/s
#      |████████████████████████████████| 522kB 8.5MB/s
#      |████████████████████████████████| 153kB 50.5MB/s
#      |████████████████████████████████| 491kB 50.7MB/s
#   Building wheel for ergo (PEP 517) ... done
#   Building wheel for country-converter (setup.py) ... done
# ERROR: chainer 6.5.0 has requirement typing-extensions<=3.6.6, but you'll have typing-extensions 3.7.4.2 which is incompatible.

# %% [markdown]
# Imports:

# %%
import ergo
import pendulum
import pandas as pd
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
# %load_ext google.colab.data_table

# %% [markdown]
# # Dashboard

# %%
metaculus = ergo.Metaculus(username="ought", password="", api_domain="pandemic")

# %% [markdown]
# ## Prediction results

# %%
results = metaculus.get_prediction_results()

# %%
results
# Out:
#             time  ...                                      question_name
# 0   1.585643e+09  ...  [short fuse] How many total confirmed deaths o...
# 1   1.585722e+09  ...  [short fuse] How many total confirmed deaths o...
# 2   1.585643e+09  ...  What will be the US unemployment rate for Marc...
# 3   1.585722e+09  ...  What will be the US unemployment rate for Marc...
# 4   1.585806e+09  ...  What will be the US unemployment rate for Marc...
# ..           ...  ...                                                ...
# 72  1.585188e+09  ...  How many total confirmed cases of novel corona...
# 73  1.585198e+09  ...  How many total confirmed cases of novel corona...
# 74  1.585292e+09  ...  How many total confirmed cases of novel corona...
# 75  1.584666e+09  ...  How many cumulative confirmed cases of coronav...
# 76  1.584666e+09  ...  How many COVID-2019 cases in South Korea will ...
#
# [77 rows x 5 columns]

# %% [markdown]
# For continuous questions, higher scores are better.

# %%
results.groupby("question_name").mean()[["score", "resolution", "time"]]
# Out:
#                                                        score  ...          time
# question_name                                                 ...
# How many COVID-2019 cases in South Korea will b...  0.438638  ...  1.584666e+09
# How many COVID-2019 cases in the United Kingdom...  1.058132  ...  1.584840e+09
# How many cumulative confirmed cases of coronavi...  1.400453  ...  1.584666e+09
# How many cumulative confirmed cases of coronavi...  1.789178  ...  1.584666e+09
# How many total confirmed cases of novel coronav...  0.326747  ...  1.585016e+09
# How many total confirmed cases of novel coronav...  1.352250  ...  1.585080e+09
# How many total confirmed cases of novel coronav... -1.144452  ...  1.585081e+09
# How many total confirmed cases of novel coronav...  0.928360  ...  1.585080e+09
# How many total confirmed cases of novel coronav...  2.294402  ...  1.585080e+09
# How many total confirmed cases of novel coronav...  0.697341  ...  1.585080e+09
# What will be the US unemployment rate for March...  2.430806  ...  1.585790e+09
# Will Florida go under lockdown between 2020-03-...  0.202500  ...  1.585831e+09
# [short fuse] How many total confirmed deaths of... -2.302869  ...  1.585682e+09
#
# [13 rows x 3 columns]

# %% [markdown]
# ## Resolved questions

# %%
resolved_predictions = metaculus.make_questions_df(metaculus.get_questions_json(question_status="resolved", player_status="predicted", pages=9999))

# %% [markdown]
# See https://pandemic.metaculus.com/questions/?order_by=-resolve_time&status=resolved&guessed_by=112004

# %%
resolved_predictions[["title", "resolve_time", "i_created", "url", "id"]]
# Out:
#                                                 title  ...    id
# 0   [short fuse] How many total confirmed deaths o...  ...  3934
# 1   What will be the US unemployment rate for Marc...  ...  3922
# 2   Will Florida go under lockdown between 2020-03...  ...  3926
# 3   How many total confirmed cases of novel corona...  ...  3705
# 4   How many total confirmed cases of novel corona...  ...  3706
# 5   How many total confirmed cases of novel corona...  ...  3712
# 6   How many total confirmed cases of novel corona...  ...  3713
# 7   How many total confirmed cases of novel corona...  ...  3711
# 8   How many COVID-2019 cases in the United Kingdo...  ...  3761
# 9   How many cumulative confirmed cases of coronav...  ...  3740
# 10  How many total confirmed cases of novel corona...  ...  3704
# 11  How many cumulative confirmed cases of coronav...  ...  3736
# 12  How many COVID-2019 cases in South Korea will ...  ...  3722
#
# [13 rows x 5 columns]

# %% [markdown]
# ## Open questions

# %%
open = metaculus.make_questions_df(metaculus.get_questions_json(question_status="open", player_status="any", pages=9999))

# %%
open
# Out:
#                                                    url  ... i_predicted
# 0    https://pandemic.metaculus.com/api2/questions/...  ...       False
# 1    https://pandemic.metaculus.com/api2/questions/...  ...       False
# 2    https://pandemic.metaculus.com/api2/questions/...  ...       False
# 3    https://pandemic.metaculus.com/api2/questions/...  ...       False
# 4    https://pandemic.metaculus.com/api2/questions/...  ...       False
# ..                                                 ...  ...         ...
# 100  https://pandemic.metaculus.com/api2/questions/...  ...       False
# 101  https://pandemic.metaculus.com/api2/questions/...  ...       False
# 102  https://pandemic.metaculus.com/api2/questions/...  ...       False
# 103  https://pandemic.metaculus.com/api2/questions/...  ...       False
# 104  https://pandemic.metaculus.com/api2/questions/...  ...       False
#
# [105 rows x 24 columns]

# %% [markdown]
# ### Published on or after Mar 25, closing on or before Apr 25

# %%
after_mar_25 = open[open["publish_time"] > pendulum.datetime(2020,3,24, tz="America/Los_Angeles")]
before_apr_25 = after_mar_25[after_mar_25["close_time"] < pendulum.datetime(2020,4,26, tz="America/Los_Angeles")]

# %%
before_apr_25[["title", "publish_time", "close_time", "i_predicted", "i_created", "page_url", "id"]]
# Out:
#                                                 title  ...    id
# 7   Will the US Strategic National Stockpile suppl...  ...  4020
# 11          Will Boris Johnson recover from COVID-19?  ...  4040
# 21  How many COVID-19 deaths will be recorded in t...  ...  3996
# 28  What will the CBO estimate to be the cost of t...  ...  3920
# 30  How many days will the average American spend ...  ...  3925
# 33  What will Washington state’s Department of Rev...  ...  3923
# 34  What will the Seattle Police Department report...  ...  3924
# 35  Will the US federal government shut down all n...  ...  3921
# 36  Will the Emergency Telework Act (S.3561) becom...  ...  3918
# 38  By May 1 will there be an iOS or Android app t...  ...  3915
# 39  By June 1, how many tests for COVID-19 will ha...  ...  3916
# 54  How many days will the city of New Orleans spe...  ...  3930
# 55  How many days will the city of Seattle spend u...  ...  3929
# 56  How many days will Washington state spend unde...  ...  3928
# 57  How many days will New York City spend under l...  ...  3927
#
# [15 rows x 7 columns]

# %% [markdown]
# # TODO:
#
# 1.   Add date and time of our latest prediction
# 2. Add everything we'd want to reflect on resolutions of predictions (see https://docs.google.com/document/d/1WfWnvDDUufHe39l2UeWZ8lfrQtEaSR9kH7KC_gtEYiQ/edit# for inspiration)
